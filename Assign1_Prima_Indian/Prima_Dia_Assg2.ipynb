# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\IBM_ADMIN\\Documents\\Reva\\Mod1\\assg2_dia.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
import matplotlib.pyplot as plt
x = df['Age']
y = df['Glucose']
z = df['Outcome']
plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
x = df['Age']
y = df['Glucose']
z = df['Outcome']
plt.scatter(x,y)
plt.show()

# %%
colors = {1:'red', 0:'green'}
plt.scatter(x,y, c=z.apply(lambda x: colors[x]))
plt.title('Prima Indian Diabities')
plt.xlabel('Age')
plt.ylabel('Glucose')
plt.show()

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
dia_true = len(df.loc[df['Outcome'] == 1])
dia_false = len(df.loc[df['Outcome'] == 0])
print("Number of Diabetic cases: {0} ".format(dia_true))
print("Number of non-diabetic cases: {0} ".format(dia_false))
# Out:
# Number of Diabetic cases: 268
# Number of non-diabetic cases: 500

# %%
glucose_value = len(df.loc[df['Glucose'] == 0])
print("Number of missing glucose cases: {0} ".format(glucose_value))
print("Number of missing glucose casesreplaced: {0} ".format(glucose_value == df['Glucose'].mean()))
# Out:
# Number of missing glucose cases: 5
# Number of missing glucose casesreplaced: False

# %%
df['Glucose'] = df['Glucose'].replace(df['Glucose'], df['Glucose'].mean())

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578    0.000000      19.355807      15.952218  115.244002
# min       0.000000  120.894531       0.000000       0.000000    0.000000
# 25%       1.000000  120.894531      62.000000       0.000000    0.000000
# 50%       3.000000  120.894531      72.000000      23.000000   30.500000
# 75%       6.000000  120.894531      80.000000      32.000000  127.250000
# max      17.000000  120.894531     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df['Glucose'][75]
# Out:
# 120.89453125

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578    0.000000      19.355807      15.952218  115.244002
# min       0.000000  120.894531       0.000000       0.000000    0.000000
# 25%       1.000000  120.894531      62.000000       0.000000    0.000000
# 50%       3.000000  120.894531      72.000000      23.000000   30.500000
# 75%       6.000000  120.894531      80.000000      32.000000  127.250000
# max      17.000000  120.894531     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
colors = {1:'red', 0:'green'}
plt.scatter(x,y, c=z.apply(lambda x: colors[x]))
plt.title('Prima Indian Diabities')
plt.xlabel('Age')
plt.ylabel('Glucose')
plt.show()

# %%
df['Glucose'].mean()
# Out:
# 120.89453125

# %%
df_mean_input
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
# 5      116
# 6       78
# 7      115
# 8      197
# 9      125
# 10     110
# 11     168
# 12     139
# 13     189
# 14     166
# 15     100
# 16     118
# 17     107
# 18     103
# 19     115
# 20     126
# 21      99
# 22     196
# 23     119
# 24     143
# 25     125
# 26     147
# 27      97
# 28     145
# 29     117
#       ...
# 738     99
# 739    102
# 740    120
# 741    102
# 742    109
# 743    140
# 744    153
# 745    100
# 746    147
# 747     81
# 748    187
# 749    162
# 750    136
# 751    121
# 752    108
# 753    181
# 754    154
# 755    128
# 756    137
# 757    123
# 758    106
# 759    190
# 760     88
# 761    170
# 762     89
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
glucose_value = len(df.loc[df['Glucose'] == 0])
print("Number of missing glucose cases: {0} ".format(glucose_value))
# Out:
# Number of missing glucose cases: 5
